# %% [markdown]
# <a href="https://colab.research.google.com/github/anumit-web/Seaborn-tutorial-3/blob/main/Seaborn_test_3_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Seaborn
#
# Python visualization library
#
# The Ultimate Python Seaborn Tutorial: Gotta Catch 'Em All
#
# https://elitedatascience.com/python-seaborn-tutorial

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")

# %%
dowjones = sns.load_dataset("dowjones") # data frame objects
dowjones.head()
# Out:
#         Date  Price
# 0 1914-12-01  55.00
# 1 1915-01-01  56.55
# 2 1915-02-01  56.00
# 3 1915-03-01  58.30
# 4 1915-04-01  66.45

# %%
dowjones = sns.load_dataset("dowjones") # data frame objects
dowjones.tail()
# Out:
#           Date   Price
# 644 1968-08-01  883.72
# 645 1968-09-01  922.80
# 646 1968-10-01  955.47
# 647 1968-11-01  964.12
# 648 1968-12-01  965.39

# %%
dowjones = sns.load_dataset("dowjones")
sns.relplot(data=dowjones, x="Date", y="Price", kind="line")

# %% [markdown]
# More complex datasets will have multiple measurements for the same value of the x variable.

# %%
fmri = sns.load_dataset("fmri")
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
fmri = sns.load_dataset("fmri")
fmri.tail()
# Out:
#      subject  timepoint event    region    signal
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899

# %%
fmri = sns.load_dataset("fmri")
sns.relplot(data=fmri, x="timepoint", y="signal", kind="line")

# %%
fmri = sns.load_dataset("fmri")
sns.relplot(
     data=fmri, kind="line",
     x="timepoint", y="signal", errorbar="sd",
)

# %% [markdown]
# ## 3d line plots using hue

# %%
fmri = sns.load_dataset("fmri")
sns.relplot(
    data=fmri, kind="line",
    x="timepoint", y="signal", hue="event",
)

# %%
fmri = sns.load_dataset("fmri")
sns.relplot(
     data=fmri, kind="line",
     x="timepoint", y="signal", hue="event", palette="Pastel1"
)

# %%
fmri = sns.load_dataset("fmri")
sns.relplot(
     data=fmri, kind="line",
     x="timepoint", y="signal", hue="event", palette="flag"
)

# %%
fmri = sns.load_dataset("fmri")
sns.relplot(
    data=fmri, kind="line",
    x="timepoint", y="signal", hue="event", palette="GnBu"
)

# %%
fmri = sns.load_dataset("fmri")
sns.relplot(
    data=fmri, kind="line",
    x="timepoint", y="signal", hue="event", palette="RdPu"
)
